# %%
import pandas as pd

# %%
# Cuando sale error por UTF-8 se utiliza encoding
df = pd.read_csv('./data/sales_data_sample.csv')
df
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Cuando sale error por UTF-8 se utiliza encoding
# ----> 2 df = pd.read_csv('./data/sales_data_sample.csv')
#       3 df
#
# ...

# %%
# Cuando sale error por UTF-8 se utiliza encoding
df_sale = pd.read_csv('./data/sales_data_sample.csv', encoding='ISO-8859-1')
df_sale
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df_sale.shape
# Out:
# (2823, 25)

# %%
df_sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %%
df_sale.isnull()
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER  SALES  \
# 0           False            False      False            False  False
# 1           False            False      False            False  False
# 2           False            False      False            False  False
# 3           False            False      False            False  False
# 4           False            False      False            False  False
# ...           ...              ...        ...              ...    ...
# 2818        False            False      False            False  False
# 2819        False            False      False            False  False
# 2820        False            False      False            False  False
# 2821        False            False      False            False  False
# 2822        False            False      False            False  False
#
#       ORDERDATE  STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  ADDRESSLINE1  \
# ...

# %%
df_sale.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
total_null = df_sale.isnull().sum().sort_values(ascending = False)
total_null
# Out:
# ADDRESSLINE2        2521
# STATE               1486
# TERRITORY           1074
# POSTALCODE            76
# ORDERNUMBER            0
# CUSTOMERNAME           0
# CONTACTFIRSTNAME       0
# CONTACTLASTNAME        0
# COUNTRY                0
# CITY                   0
# ADDRESSLINE1           0
# PHONE                  0
# PRODUCTCODE            0
# QUANTITYORDERED        0
# MSRP                   0
# PRODUCTLINE            0
# YEAR_ID                0
# MONTH_ID               0
# QTR_ID                 0
# STATUS                 0
# ORDERDATE              0
# SALES                  0
# ORDERLINENUMBER        0
# PRICEEACH              0
# DEALSIZE               0
# dtype: int64

# %%
porcentaje_nulos = (df_sale.isnull().sum()/df_sale.isnull().count()).sort_values(ascending = False)
porcentaje_nulos
# Out:
# ADDRESSLINE2        0.893022
# STATE               0.526390
# TERRITORY           0.380446
# POSTALCODE          0.026922
# ORDERNUMBER         0.000000
# CUSTOMERNAME        0.000000
# CONTACTFIRSTNAME    0.000000
# CONTACTLASTNAME     0.000000
# COUNTRY             0.000000
# CITY                0.000000
# ADDRESSLINE1        0.000000
# PHONE               0.000000
# PRODUCTCODE         0.000000
# QUANTITYORDERED     0.000000
# MSRP                0.000000
# PRODUCTLINE         0.000000
# YEAR_ID             0.000000
# MONTH_ID            0.000000
# QTR_ID              0.000000
# STATUS              0.000000
# ORDERDATE           0.000000
# SALES               0.000000
# ORDERLINENUMBER     0.000000
# PRICEEACH           0.000000
# DEALSIZE            0.000000
# dtype: float64

# %%
#axis = 1 => lo ordena de forma horizontal
missing_data = pd.concat([total_null, porcentaje_nulos], axis=1, keys=['total_null','porcentaje_nulos'])
missing_data
# Out:
#                   total_null  porcentaje_nulos
# ADDRESSLINE2            2521          0.893022
# STATE                   1486          0.526390
# TERRITORY               1074          0.380446
# POSTALCODE                76          0.026922
# ORDERNUMBER                0          0.000000
# CUSTOMERNAME               0          0.000000
# CONTACTFIRSTNAME           0          0.000000
# CONTACTLASTNAME            0          0.000000
# COUNTRY                    0          0.000000
# CITY                       0          0.000000
# ADDRESSLINE1               0          0.000000
# PHONE                      0          0.000000
# PRODUCTCODE                0          0.000000
# QUANTITYORDERED            0          0.000000
# MSRP                       0          0.000000
# PRODUCTLINE                0          0.000000
# YEAR_ID                    0          0.000000
# MONTH_ID                   0          0.000000
# QTR_ID                     0          0.000000
# ...

# %%
df_sale.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
df_sale[['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH']]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH
# 0           10107               30      95.70
# 1           10121               34      81.35
# 2           10134               41      94.74
# 3           10145               45      83.26
# 4           10159               49     100.00
# ...           ...              ...        ...
# 2818        10350               20     100.00
# 2819        10373               29     100.00
# 2820        10386               43     100.00
# 2821        10397               34      62.24
# 2822        10414               47      65.52
#
# [2823 rows x 3 columns]

# %%
df_sale.select_dtypes
# Out:
# <bound method DataFrame.select_dtypes of       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
# ...

# %%
df_sale.select_dtypes(include=[float,int])
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       QTR_ID  MONTH_ID  YEAR_ID  MSRP
# 0          1         2     2003    95
# ...

# %%
df_sale.loc[0,['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH']]
# Out:
# ORDERNUMBER        10107
# QUANTITYORDERED       30
# PRICEEACH           95.7
# Name: 0, dtype: object

# %%
# Trae los registros de 0 hasta 5
df_sale.loc[0:5,['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH']]
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH
# 0        10107               30      95.70
# 1        10121               34      81.35
# 2        10134               41      94.74
# 3        10145               45      83.26
# 4        10159               49     100.00
# 5        10168               36      96.66

# %%
# Nos traelas columnas que contengan la palabra dada
df_sale.filter(like='ORDER')
# Out:
#       ORDERNUMBER  QUANTITYORDERED  ORDERLINENUMBER        ORDERDATE
# 0           10107               30                2   2/24/2003 0:00
# 1           10121               34                5    5/7/2003 0:00
# 2           10134               41                2    7/1/2003 0:00
# 3           10145               45                6   8/25/2003 0:00
# 4           10159               49               14  10/10/2003 0:00
# ...           ...              ...              ...              ...
# 2818        10350               20               15   12/2/2004 0:00
# 2819        10373               29                1   1/31/2005 0:00
# 2820        10386               43                4    3/1/2005 0:00
# 2821        10397               34                1   3/28/2005 0:00
# 2822        10414               47                9    5/6/2005 0:00
#
# [2823 rows x 4 columns]

# %%
df_sale.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df_filter = df_sale[(df_sale.STATE == 'NY') & (df_sale.COUNTRY == 'USA')]
df_filter
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 11          10237               23     100.00                7  2333.12
# 19          10329               42     100.00                1  4396.14
# 31          10163               21     100.00                1  4860.24
# 54          10107               39      99.91                5  3896.49
# ...           ...              ...        ...              ...      ...
# 2737        10337               36      71.89                7  2588.04
# 2759        10308               39      68.11               15  2656.29
# 2788        10329               44      86.13                8  3789.72
# 2809        10248               23      65.52                9  1506.96
# 2817        10337               42      97.16                5  4080.72
#
#             ORDERDATE     STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df_filter = df_sale.query('STATE == "NY" and COUNTRY == "USA" ')
df_filter
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 11          10237               23     100.00                7  2333.12
# 19          10329               42     100.00                1  4396.14
# 31          10163               21     100.00                1  4860.24
# 54          10107               39      99.91                5  3896.49
# ...           ...              ...        ...              ...      ...
# 2737        10337               36      71.89                7  2588.04
# 2759        10308               39      68.11               15  2656.29
# 2788        10329               44      86.13                8  3789.72
# 2809        10248               23      65.52                9  1506.96
# 2817        10337               42      97.16                5  4080.72
#
#             ORDERDATE     STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
# Utilizar las triple comillas para escribir en varias lineas
df_filter = df_sale.query("""
    STATE == "NY" and COUNTRY == "USA"
""")
df_filter
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 11          10237               23     100.00                7  2333.12
# 19          10329               42     100.00                1  4396.14
# 31          10163               21     100.00                1  4860.24
# 54          10107               39      99.91                5  3896.49
# ...           ...              ...        ...              ...      ...
# 2737        10337               36      71.89                7  2588.04
# 2759        10308               39      68.11               15  2656.29
# 2788        10329               44      86.13                8  3789.72
# 2809        10248               23      65.52                9  1506.96
# 2817        10337               42      97.16                5  4080.72
#
#             ORDERDATE     STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df_sale.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
# Promedio de ventas por pais
df_sale[['COUNTRY','SALES']].groupby('COUNTRY').mean()
# Out:
#                    SALES
# COUNTRY
# Australia    3408.773514
# Austria      3673.864182
# Belgium      3285.230909
# Canada       3201.122286
# Denmark      3899.002381
# Finland      3582.412065
# France       3537.950701
# Germany      3556.001452
# Ireland      3609.776875
# Italy        3315.701858
# Japan        3618.611731
# Norway       3617.220000
# Philippines  3615.989615
# Singapore    3651.752025
# Spain        3554.640117
# Sweden       3684.459825
# Switzerland  3797.211613
# UK           3325.558750
# USA          3613.528715

# %%
# Promedio de ventas por pais
df_sale[['COUNTRY','SALES']].groupby('COUNTRY').mean().sort_values(by='SALES',ascending = False)
# Out:
#                    SALES
# COUNTRY
# Denmark      3899.002381
# Switzerland  3797.211613
# Sweden       3684.459825
# Austria      3673.864182
# Singapore    3651.752025
# Japan        3618.611731
# Norway       3617.220000
# Philippines  3615.989615
# USA          3613.528715
# Ireland      3609.776875
# Finland      3582.412065
# Germany      3556.001452
# Spain        3554.640117
# France       3537.950701
# Australia    3408.773514
# UK           3325.558750
# Italy        3315.701858
# Belgium      3285.230909
# Canada       3201.122286

# %%
df_sale[['COUNTRY','SALES','STATE']].groupby(['COUNTRY','STATE']).mean().sort_values(by='SALES',ascending = False)
# Out:
#                                SALES
# COUNTRY   STATE
# Australia Queensland     3964.608000
# USA       NJ             3963.247143
#           CT             3912.480000
#           NH             3873.097059
# Japan     Tokyo          3767.585625
# USA       PA             3644.363600
#           NY             3631.144719
#           CA             3619.091899
#           MA             3507.598526
# Australia Victoria       3404.959872
# Japan     Osaka          3380.253500
# Canada    Quebec         3372.945000
# Australia NSW            3321.381630
# Canada    BC             3122.370208
# UK        Isle of Wight  3009.263077
# USA       NV             2853.485517
